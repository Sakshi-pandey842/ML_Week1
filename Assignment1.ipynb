# %% [markdown]
# TASK 01

# %%
name = input("What is your name? ")
age = input("How old are you? ")
location = input("Where are you from? ")
interest = input("What is something you're interested in? ")

print("\n--- About Me ---")
print(f"Hi, my name is {name}. I'm {age} years old and I live in {location}.")
print(f"I'm really interested in {interest}. Nice to meet you!")
# Out:
# What is your name?  sakshi
# How old are you?  19
# Where are you from?  bhopal
# What is something you're interested in?  singing
# --- About Me ---
# Hi, my name is sakshi. I'm 19 years old and I live in bhopal.
# I'm really interested in singing. Nice to meet you!

# %% [markdown]
# Task 02

# %%
total = 0
while True:
    name = input("Item name (or 'done'): ")
    if name.lower() == 'done':
        break
    price = float(input("Price: "))
    qty = int(input("Quantity: "))
    total += price * qty

gst = total * 0.18
final_total = total + gst

print(f"\nSubtotal: ₹{total:.2f}")
print(f"GST (18%): ₹{gst:.2f}")
print(f"Total: ₹{final_total:.2f}")

# %% [markdown]
# Task 03

# %%
marks = float(input("Enter your marks (0-100): "))

if marks >= 90:
    grade = 'A'
elif marks >= 75:
    grade = 'B'
elif marks >= 60:
    grade = 'C'
elif marks >= 40:
    grade = 'D'
else:
    grade = 'Fail'

print(f"Your Grade: {grade}")

# %% [markdown]
# Task 04

# %%
temps = []
for i in range(5):
    t = float(input(f"Enter temperature for day {i+1}: "))
    temps.append(t)

avg = sum(temps) / 5
print(f"Average temperature: {avg:.2f}")

# %% [markdown]
# Task 05

# %%
import random
secret = random.randint(1, 100)

for i in range(5):
    guess = input(f"Attempt {i+1}/5 - Guess the number: ")
    if not guess.isdigit():
        print("Invalid input, try again.")
        continue
    if int(guess) == secret:
        print("Correct! You guessed it!")
        break
    else:
        print("Wrong guess.")
else:
    print(f"Out of attempts! The number was {secret}.")
