# %%
print("Quize game")
plyr=input("Do you want to play?\n")
if plyr.lower() == "yes":
    print("ok lets play")
else:
    
     quit()  
scr=0
      
q1=input("Q1.Which country launched the global campaign titled Preventing Future Encephalitis Climate Change and Infectious Disease?\n")     
if q1.lower()==" United Kingdom " or "UK":
    print("you are correct")
    scr+=1
else:
    print("you are wrong!") 
       
q2=input("Q2.What is the new income tax rebate limit announced in the 2025 Union Budget of India?\n")    
if q2.lower()=="12.75 lakh":
    print("you are correct")
    scr+=1
else:
    print("you are wrong!")  

q3=input("Q3.Which Indian state hosted the 2025 Khelo India Youth Games for the first time?\n")  
if q3.lower()=="Bihar"or "bihar":
    print("you are correct")
    scr+=1
else:
    print("you are wrong!") 
    
print("your score:",scr)
# Out:
# Quize game
# Do you want to play?
#  yes
# ok lets play
# Q1.Which country launched the global campaign titled Preventing Future Encephalitis Climate Change and Infectious Disease?
#  uk
# you are correct
# Q2.What is the new income tax rebate limit announced in the 2025 Union Budget of India?
#  12.75 lakh
# you are correct
# Q3.Which Indian state hosted the 2025 Khelo India Youth Games for the first time?
#  bihar
# you are correct
# your score: 3
